# %% [markdown]
# <h1> Test de Pandas<h1>

# %%
########################### ouverture du fichier et visualisation des premières lignes
import pandas as pd
df = pd.read_csv("/home/mathieu.vialat@Digital-Grenoble.local/Documents/Projet_arbres/data/ESP_PUBLIC.IDENTITE_ARBRE.csv", sep = ',', header = 0, index_col = False, names = None)
df.head()
# Out:
#    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0          23881  ESP29285  ESP29285   VEG  VEGETATION     ESP01
# 1          23886  ESP29286  ESP29286   VEG  VEGETATION     ESP01
# 2          23891  ESP29287  ESP29287   VEG  VEGETATION     ESP01
# 3          23895  ESP29288  ESP29288   VEG  VEGETATION     ESP01
# 4          12182  ESP29289  ESP29289   VEG  VEGETATION     ESP01
#
#   CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP639  ...
# 1          Arbre         ESP187        Bois semi naturel       ESP53  ...
# 2          Arbre         ESP174  Arbre d'espaces ouverts     ESP1058  ...
# 3          Arbre         ESP151          Arbre de voirie      ESP616  ...
# 4          Arbre         ESP174  Arbre d'espaces ouverts     ESP1213  ...
#
#   COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# ...

# %%
########################### liste des noms de colonnes
list_columns = df.columns.tolist()
print(list_columns)
# Out:
# ['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE', 'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC', 'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE', 'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE', 'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE', 'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE', 'GeoJSON']

# %%
################## fréquence d'apparition des valeurs d'une colonne
df['GENRE_BOTA'].value_counts()
# Out:
# Acer           5055
# Platanus       4492
# Pinus          1962
# Tilia          1740
# Fraxinus       1505
#                ...
# Castanea          1
# Eucalyptus        1
# Poncinos          1
# Sciadopitys       1
# Nyssa             1
# Name: GENRE_BOTA, Length: 119, dtype: int64

# %%
################## fréquence d'apparition d'une valeur dans une colonne
df['GENRE_BOTA'].value_counts()['Acer']
# Out:
# 5055

# %%
###################### enlever les index
new_df = df.reset_index(drop=True,inplace=False)
new_df.head()
############# Pas de colonne indice donc pas de changement?
# Out:
#    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0          23881  ESP29285  ESP29285   VEG  VEGETATION     ESP01
# 1          23886  ESP29286  ESP29286   VEG  VEGETATION     ESP01
# 2          23891  ESP29287  ESP29287   VEG  VEGETATION     ESP01
# 3          23895  ESP29288  ESP29288   VEG  VEGETATION     ESP01
# 4          12182  ESP29289  ESP29289   VEG  VEGETATION     ESP01
#
#   CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP639  ...
# 1          Arbre         ESP187        Bois semi naturel       ESP53  ...
# 2          Arbre         ESP174  Arbre d'espaces ouverts     ESP1058  ...
# 3          Arbre         ESP151          Arbre de voirie      ESP616  ...
# 4          Arbre         ESP174  Arbre d'espaces ouverts     ESP1213  ...
#
#   COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# ...

# %%
######################### enlever une colonne
new_df.drop(columns = ['CODE', 'NOM'])
new_df.head(10)
print(len(new_df))
###################### pour enregistrer la modif new_df = new_df.drop(columns = ['CODE', 'NOM'])
# Out:
# 31618

# %%
######################### selectionner les 50 premières lignes
df_prem = df.iloc[0:50]
print(len(df_prem))
# Out:
# 50

# %%
####################### itérer sur row ou columns
somme = 0
for i,row in df.iterrows():
    somme+=int(row['ADR_SECTEUR'])
print(somme)
#### possible d'utiliser aussi itertuples pour avoir les deux
# Out:
# 121439

# %%
######################## trier une colonne
df.sort_values(by = ['SOUS_CATEGORIE'], ascending = True)
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 15800          38042  ESP38018  ESP38018   VEG  VEGETATION     ESP01
# 12179            486  ESP14150  ESP14150   VEG  VEGETATION     ESP01
# 18876          21207  ESP19712  ESP19712   VEG  VEGETATION     ESP01
# 18875          21204  ESP19711  ESP19711   VEG  VEGETATION     ESP01
# 18874          21202  ESP19710  ESP19710   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 3032           10502   ESP4528   ESP4528   VEG  VEGETATION     ESP01
# 29840          28349  ESP26160  ESP26160   VEG  VEGETATION     ESP01
# 29841          28354  ESP26161  ESP26161   VEG  VEGETATION     ESP01
# 26786          32078  ESP32804  ESP32804   VEG  VEGETATION     ESP01
# 15138          14274  ESP17712  ESP17712   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
############## appliquer une fonction à une colonne
df['ELEM_POINT_ID'].apply(lambda x: x+1)
# Out:
# 0        23882
# 1        23887
# 2        23892
# 3        23896
# 4        12183
#          ...
# 31613    30028
# 31614    30029
# 31615    30030
# 31616    30031
# 31617    30032
# Name: ELEM_POINT_ID, Length: 31618, dtype: int64

# %%
##################### appliquer à tout les éléments d'un df
new_df2 = df.applymap(lambda x: x)

# %%
##################### Choisir elements si dans une liste
###df[df[''].isin(list)]
### si pas dans la liste df[~df[''].isin(list)]

# %%
################ Groupby and aggregate
df_new3 = df.groupby(['GENRE_BOTA'])
df_new3.head()
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              23881  ESP29285  ESP29285   VEG  VEGETATION     ESP01
# 1              23886  ESP29286  ESP29286   VEG  VEGETATION     ESP01
# 2              23891  ESP29287  ESP29287   VEG  VEGETATION     ESP01
# 3              23895  ESP29288  ESP29288   VEG  VEGETATION     ESP01
# 4              12182  ESP29289  ESP29289   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 30654          27088  ESP22556  ESP22556   VEG  VEGETATION     ESP01
# 30656          27097  ESP22558  ESP22558   VEG  VEGETATION     ESP01
# 31010          30287  ESP31454  ESP31454   VEG  VEGETATION     ESP01
# 31011          30288  ESP31455  ESP31455   VEG  VEGETATION     ESP01
# 31081          30294  ESP31461  ESP31461   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# ...

# %%
df_new3 = df.groupby(['GENRE_BOTA']).agg({'ELEM_POINT_ID':'mean'})
df_new3.head()
# Out:
#             ELEM_POINT_ID
# GENRE_BOTA
# Abies        17000.600000
# Acacia       40701.000000
# Acer         19008.959446
# Aesculus     15275.409978
# Ailanthus    17253.556962

# %%
################## concatenate dataframes
Double = pd.concat([df, new_df], axis=0)
print(len(Double))
# Out:
# 63236

# %%
###################### merger deux dataframe
df_merged = df.merge(new_df, on=['ELEM_POINT_ID'], how='inner')
df_merged.head()
# Out:
#    ELEM_POINT_ID    CODE_x     NOM_x GENRE_x GENRE_DESC_x CATEGORIE_x  \
# 0          23881  ESP29285  ESP29285     VEG   VEGETATION       ESP01
# 1          23886  ESP29286  ESP29286     VEG   VEGETATION       ESP01
# 2          23891  ESP29287  ESP29287     VEG   VEGETATION       ESP01
# 3          23895  ESP29288  ESP29288     VEG   VEGETATION       ESP01
# 4          12182  ESP29289  ESP29289     VEG   VEGETATION       ESP01
#
#   CATEGORIE_DESC_x SOUS_CATEGORIE_x    SOUS_CATEGORIE_DESC_x CODE_PARENT_x  \
# 0            Arbre           ESP174  Arbre d'espaces ouverts        ESP639
# 1            Arbre           ESP187        Bois semi naturel         ESP53
# 2            Arbre           ESP174  Arbre d'espaces ouverts       ESP1058
# 3            Arbre           ESP151          Arbre de voirie        ESP616
# 4            Arbre           ESP174  Arbre d'espaces ouverts       ESP1213
#
#    ... COURRIER_y  IDENTIFIANTPLU_y TYPEIMPLANTATIONPLU_y  \
# ...
